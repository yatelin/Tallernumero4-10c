# %%
print ("Hola Mundo")
# Out:
# Hola Mundo

# %%
integrantes= "Samuel Yate y Martin Verdugo"
print(integrantes)
# Out:
# Samuel Yate y Martin Verdugo

# %%
Grado= "10°C"
print(Grado)
# Out:
# 10°C

# %%
print(66+1)
# Out:
# 67

# %%
print(100-33)
# Out:
# 67

# %%
print(32/2)
# Out:
# 16.0

# %%
print(5*5)
# Out:
# 25
